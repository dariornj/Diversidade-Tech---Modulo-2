# %% [markdown]
# ## Lógica de programação II - Tuplas
#
# Na aula de hoje, iremos explorar os seguintes tópicos em Python:
# - Importando módulos
# - Revisão de listas
# - Tuplas

# %% [markdown]
# ### Importando módulos em Python
#
# Muitos dos problemas de programação já foram resolvidos por outras pessoas, por exemplo calcular o `log` de um número. Por este motivo diversas linguagens de programação, como Python e JavaScript, apresentam bibliotecas que facilitam o uso dessas funcionalidades sem a necessidade de programar do zero!
#
# Nas linguagens mais populares, há uma grande comunidade que desenvolve esses módulos facilitando ainda mais o nosso dia-a-dia, como por exemplo o `numpy`, `pandas` e o `matplotlib`, bibliotecas que iremos explorar nos próximos módulos!
#
# Para utilizar esses módulos, há três principais fontes:
# - As bibliotecas já distribuídas com o Python. Para saber mais temos a [PEP206](https://peps.python.org/pep-0206/)
#   - [Biblioteca padrão](https://docs.python.org/3/library/)
# - Bibliotecas de terceiros disponíveis pelo [PyPi](https://pypi.org/)
# - A última é o [github](https://github.com/)
#
# Para instalar módulos de terceiros podemos utilizar podemos utilizar o comando:
# `pip install <nome do pacote>`
#
# `conda install <nome do pacote>`
#
# Um detalhe é que o utilizando o `conda` nem sempre o pacote está disponível, mas está disponível no PyPi, sendo o `pip` a única alternativa.
#
# Para importar um módulo utilizamos:
#
# `import <nome do módulo>`
#
# `from <nome do módulo> import <nome do submódulo>`
#
# Ambos irão disponibilizar o pacote para serem utilizados na forma de código. A principal diferença é que no `from ... import ...` utilizamos menos memória, já que somente uma parte do módulo será importado, sendo uma boa prática a ser realizada.

# %%
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-1.5.0-cp310-cp310-win_amd64.whl (10.4 MB)
#      ---------------------------------------- 10.4/10.4 MB 2.6 MB/s eta 0:00:00
# Collecting pytz>=2020.1
#   Downloading pytz-2022.4-py2.py3-none-any.whl (500 kB)
#      -------------------------------------- 500.8/500.8 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: six>=1.5 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.5.0 pytz-2022.4
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seaborn
#   Downloading seaborn-0.12.0-py3-none-any.whl (285 kB)
#      -------------------------------------- 285.1/285.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.0)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (4.37.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.4)
# Requirement already satisfied: six>=1.5 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.0
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (3.6.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: numpy>=1.19 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\dario\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importando a função `default_timer` do módulo `timeit`
from timeit import default_timer as timer
# Importando a biblioteca de estatística
import statistics

# Bibliotecas para visualização de dados
import matplotlib.pyplot as plt
import seaborn as sns

# Biblioteca para manipulação de dados estruturados (tabelas)
import pandas as pd

# %% [markdown]
# ### Listas
#
# Listas são uma estrutura de dados que permitem armazenar de forma ordenada diversos objetos (valores), como `int`, `float`, `str`, outras listas, e etc.
#
# Podemos pensar nas listas como uma **corrente** em que cada elemento está conectado entre si, como se fosse um trem!
#
# Dessa forma, assim como no trem sabemos qual o primeiro vagão, o segundo, e assim por diante até alcançar o último vagão.
#
# No caso das listas, os vagões são representados por seus **índices**, sendo ele um inteiro (`int`) iniciando no valor zero (0) e incrementando com o tamanho da lista.

# %%
# Criando listas vazias
lista1 = list() # Uma lista vazia (sem elementos)
lista2 = []     # Uma lista vazia

# Imprimindo as listas criadas
print('lista1:', lista1)
print(f"lista2: {lista2}")

# Ambas as formas retornam o mesmo tipo de objeto (lista) portanto são "identicas"
print("As listas são iguais?", lista1 == lista2)
# Out:
# lista1: []
# lista2: []
# As listas são iguais? True

# %%
# Criando uma lista com strings
frutas = ['banana', 'uva', 'abacaxi']

# Imprimindo a lista de frutas
print(f'frutas: {frutas}')

# Listas podem conter diversos tipos
lista_variada = [10, 2.75, 'abacate', True]

# Imprimindo a lista_variada
print(f'lista_variada: {lista_variada}')

# As listas podem conter listas (lista de listas)
lista_de_listas = [
    ['João', 32, 'SP'],
    ['Maria', 25, 'RJ']
]
# Imprimindo a lista de listas
print(f'lista_de_listas: {lista_de_listas}')
# Out:
# frutas: ['banana', 'uva', 'abacaxi']
# lista_variada: [10, 2.75, 'abacate', True]
# lista_de_listas: [['João', 32, 'SP'], ['Maria', 25, 'RJ']]

# %%
# Pegando os elementos da lista

# Primeiro elemento da lista
print('Primeiro elemento da lista fruta:', frutas[0])  
# Segundo elemento da lista
print('Segundo elemento da lista fruta:', frutas[1])
# Último elemento da lista
print('Ultimo elemento da lista variada:', lista_variada[-1]) 
# Primeiro elemento da lista (que é outra lista)
print('Pegando o primeiro elemento da lista de listas:', lista_de_listas[0]) 
# Pegando o primeiro elemento (lista) e dentro dessa pegando o segundo elemento
print('Pegando o primeiro elemento da lista de listas, apenas a idade', lista_de_listas[0][1])

# Fatiando (slice) a lista
# Pegando os dois últimos elementos
print('Os últimos dois elementos:', lista_variada[-2:])
# Pegando do terceiro elemento em diante
print('Os últimos dois elementos:', lista_variada[2:])
# Pegando os dois primeiros elementos
print('Os primeiros dois elementos:', lista_variada[0:2])
# Pegando todos os elementos até o penúltimo
print('Os primeiros dois elementos:', lista_variada[:-2])
# Pegando os dois primeiros elementos
print('Os primeiros dois elementos:', lista_variada[:2])
# Out:
# Primeiro elemento da lista fruta: banana
# Segundo elemento da lista fruta: uva
# Ultimo elemento da lista variada: True
# Pegando o primeiro elemento da lista de listas: ['João', 32, 'SP']
# Pegando o primeiro elemento da lista de listas, apenas a idade 32
# Os últimos dois elementos: ['abacate', True]
# Os últimos dois elementos: ['abacate', True]
# Os primeiros dois elementos: [10, 2.75]
# Os primeiros dois elementos: [10, 2.75]
# Os primeiros dois elementos: [10, 2.75]

# %%
# Descobrindo o tamanho da lista, utilizando a função `len`
print('Tamanho da lista_variada:', len(lista_variada))
# Out:
# Tamanho da lista_variada: 4

# %% [markdown]
# #### Iterando uma lista
#
# Uma forma de auxiliar na programação é falar o que o algoritmo (procedimento)deve fazer.
#
# Por exemplo, uma possível tarefa seria: **quero verificar quais elementos da minha lista**.
#
# Uma possível solução seria:
# - Para cada elemento da lista
# - Imprima esse elemento
#
# O que acabamos de fazer é um pseudocódigo
#
# Outros exemplos de [pseudocódigo](https://www.unf.edu/~broggio/cop2221/2221pseu.htm)

# %%
# - Para cada elemento da nossa lista
# - Imprima esse elemento

# Percorrendo os elementos da lista variada
for elemento in lista_variada:
  # Aqui estamos imprimindo cada elemento da lista
  print(elemento)
# Out:
# 10
# 2.75
# abacate
# True

# %% [markdown]
# Podemos melhorar o código acima, já que sabemos que a lista é composta por índices.
#
# - Para cada elemento da nossa lista
# - Imprima esse elemento, além do seu indice e o total da lista
#
# Por exemplo:
#
# No primeiro elemento teriamos:
#
# `>>> #1/4: 10`
#
# No segundo elemento:
#
# `>>> #2/4: 2.75`
#
# Para tal podemos utilizar a função enumerate!

# %%
# Iterando sobre a lista com o `enumerate`
# O Enumerate permite adicionar um número ("indice") para a nossa contagem da lista
for idx, elemento in enumerate(range(10, 100, 10)):
  # Imprimindo o indice `idx`, além do elemento da lista
  print('indice:', idx, 'elemento:', elemento)
# Out:
# indice: 0 elemento: 10
# indice: 1 elemento: 20
# indice: 2 elemento: 30
# indice: 3 elemento: 40
# indice: 4 elemento: 50
# indice: 5 elemento: 60
# indice: 6 elemento: 70
# indice: 7 elemento: 80
# indice: 8 elemento: 90

# %%
# Verificando o "manual" de uma função ou classe.
# O "manual" é conhecido como docstring
enumerate??
# Out:
# Init signature: enumerate(iterable, start=0)
# Docstring:
# Return an enumerate object.
#
#   iterable
#     an object supporting iteration
#
# The enumerate object yields pairs containing a count (from start, which
# defaults to zero) and a value yielded by the iterable argument.
#
# enumerate is useful for obtaining an indexed list:
#     (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
# Type:           type
# Subclasses:

# %%
# Podemos modificar qual o inicio da contagem com o parâmetro `start`
# Ao adicionar o `start=1` a contagem irá ocorrer a partir do número 1 e não zero como padrão
for idx, elemento in enumerate(range(10, 100, 10), start=1):
  # Imprimindo o indice `idx`, além do elemento da lista
  print('indice:', idx, 'elemento:', elemento)

# %% [markdown]
# **Drops**
#
# Crie um laço (loop) que obedeça o seguinte pseudocódigo:
#
# - Para cada elemento da nossa lista
# - Imprima esse elemento, além do seu indice e o total da lista
#
# Por exemplo:
#
# Utilizando a `lista_variada`
#
# No primeiro elemento teriamos:
#
# `>>> #1/4: 10`
#
# No segundo elemento:
#
# `>>> #2/4: 2.75`

# %%
# Criando uma lista de frutas
frutas = ['banana', 'maca', 'uva', 'pera', 'limao', 'abacate']

for i, fruta in enumerate(frutas, start=1): # Troque os ... pelo código
  print(f'#{i}/{len(frutas)}: {fruta}')
# Out:
# #1/6: banana
# #2/6: maca
# #3/6: uva
# #4/6: pera
# #5/6: limao
# #6/6: abacate

# %% [markdown]
# Adicionando elementos na lista

# %%
# Adicionando elementos com `append`
frutas.append('lichia')

print(frutas)
# Out:
# ['banana', 'maca', 'uva', 'pera', 'limao', 'abacate', 'lichia']

# %%
# Percorrendo a lista e imprimindo o índice e a fruta (elemento)
for idx, fruta in enumerate(frutas, start=1):
  print(f'#{idx}/{len(frutas)}: {fruta}')
# Out:
# #1/7: banana
# #2/7: maca
# #3/7: uva
# #4/7: pera
# #5/7: limao
# #6/7: abacate
# #7/7: lichia

# %% [markdown]
# **Concatenação de listas**

# %%
# Definindo duas listas
ds = ['Python', 'SQL', 'R']
web = ['HTML', 'CSS', 'JavaScript']

# Concatenando as listas com o operador `+`
linguagens_mais = ds + web
print(linguagens_mais)

# Concatenando as listas com o método `extend`
linguagens_extend = ds
linguagens_extend.extend(web)
print(linguagens_extend)
# Out:
# ['Python', 'SQL', 'R', 'HTML', 'CSS', 'JavaScript']
# ['Python', 'SQL', 'R', 'HTML', 'CSS', 'JavaScript']

# %% [markdown]
# **Cuidado com as listas!**
#
# Há dois comportamentos, shalow copy e deep copy
#
# Para saber mais temos [esse artigo](https://realpython.com/copying-python-objects/#:~:text=A%20shallow%20copy%20means%20constructing,of%20the%20child%20objects%20themselves.)

# %%
ds = ['Python', 'SQL', 'R']
web = ['HTML', 'CSS', 'JavaScript']
linguagens_mais = ds + web
print(f'''
Utilizando o operados "+"
ds [id:{id(ds)}]: {ds}
web [id: {id(web)}]: {web}
linguagens [id: {id(linguagens_mais)}]: {linguagens_mais}
''')
linguagens_extend = ds
print(f'''
Antes de utilizar o extend
ds [id:{id(ds)}]: {ds}
web [id: {id(web)}]: {web}
linguagens [id: {id(linguagens_extend)}]: {linguagens_extend}
''')

linguagens_extend.extend(web)

print(f'''
Após utilizar o extend
ds [id:{id(ds)}]: {ds}
web [id: {id(web)}]: {web}
linguagens [id: {id(linguagens_extend)}]: {linguagens_extend}
''')
# Out:
# Utilizando o operados "+"
# ds [id:2422964253376]: ['Python', 'SQL', 'R']
# web [id: 2422660333504]: ['HTML', 'CSS', 'JavaScript']
# linguagens [id: 2422948983168]: ['Python', 'SQL', 'R', 'HTML', 'CSS', 'JavaScript']
#
#
# Antes de utilizar o extend
# ds [id:2422964253376]: ['Python', 'SQL', 'R']
# web [id: 2422660333504]: ['HTML', 'CSS', 'JavaScript']
# linguagens [id: 2422964253376]: ['Python', 'SQL', 'R']
#
#
# Após utilizar o extend
# ds [id:2422964253376]: ['Python', 'SQL', 'R', 'HTML', 'CSS', 'JavaScript']
# web [id: 2422660333504]: ['HTML', 'CSS', 'JavaScript']
# linguagens [id: 2422964253376]: ['Python', 'SQL', 'R', 'HTML', 'CSS', 'JavaScript']

# %% [markdown]
# Qual utilizamos o id, retornamos o id único do objeto. Podemos pensar como sendo o endereço de memória do objeto!
#
# Por curiosidade, para economizar memória o Python muitas vezes aloca valores iguais no mesmo endereço de memória, por este motivo ocorreu o comportamento inesperado com a lista!
#
# O mesmo ocorre com valores númericos, como no exemplo abaixo

# %%
var1 = 5
var2 = 5
print(var1 == var2)
# Com valores númericos o id é o mesmo (mesmo endereço de memória)
print(id(var1) == id(var2))
# Out:
# True
# True

# %% [markdown]
# **Curiosidade**
#
# Listas são uma estrutura em cadeia, no Python é utilizada a estrutura de dados conhecido como `Dynamic array`, permitindo um acesso rápido ao elemento assim como inserção no fim da lista (`append`) (O(1)), porém com inserção lenta no meio da lista.
#
# Esse comportamento ocorre, por que imagine que precisamos "quebrar" a corrente para inserir um novo elo, e depois in reconstruindo a corrente elo por elo! Já no fim da corrente, basta inserir um elo novo sem precisar "quebrar" a corrente.
#
# Conhecer sobre estrutura de dados permite que criemos softwares com alta performance computacional!
#
# Para saber mais sobre estrutura de dados de listas [clique aqui](https://en.wikipedia.org/wiki/Dynamic_array#Performance)

# %%
ls = list(range(10_000))
insert_end_ls = []
for _ in range(1000):
  start = timer()
  ls.append(_)
  end = timer()
  insert_end_ls.append(end-start)

# %%
ls = list(range(10_000))
insert_middle_ls = []
for _ in range(1000):
  start = timer()
  ls.insert(len(ls)//2, _)
  end = timer()
  insert_middle_ls.append(end-start)

# %%
# Não se preocupe com o código abaixo! Iremos explorar mais no módulo seguinte.
data = pd.DataFrame(
    {"value": insert_end_ls + insert_middle_ls,
     "index": ['end'] * len(insert_end_ls) + ['middle'] * len(insert_middle_ls)
    }
)

sns.boxplot(y='value', x='index', data=data, showfliers=False)
plt.show()

# %%
media_append = statistics.mean(insert_end_ls)
media_insert = statistics.mean(insert_middle_ls)
print(f'''Performance append vs insert
Media append:          {media_append}
Media insert:          {media_insert}
Razão (insert/append): {media_insert/media_append:.2f}
''')
# Out:
# Performance append vs insert
# Media append:          1.1709998943842948e-07
# Media insert:          1.6533998714294285e-06
# Razão (insert/append): 14.12

# %% [markdown]
# ### Tuplas
#
# Até o momento, temos utilizado **listas** pra armazenar uma coleção de dados.
#
# Aprenderemos agora sobre uma nova **estrutura de dados**: tuplas!
#
# Tuplas são estruturas bastante parecidas com listas:
#
# - Podem guardar **tipos diferentes de dados**.
# - São indexadas (podemos **acessar elementos por índices**).
# - São iteráveis (**podemos percorrer com o `for`**).

# %%
# Criando uma tupla vazia
tupla1 = tuple() # Uma tupla vazia
tupla2 = ()      # Outra tupla vazia
print(tupla1)
# Out:
# ()

# %%
linguagens = ('Python', 'SQL', 'R') # Tupla com três elementos
print(linguagens)
# Out:
# ('Python', 'SQL', 'R')

# %%
dados_variados = (20, 2.17, False, 'Ana') # Tupla com tipos diferentes
print('dados_variados', dados_variados)
# Out:
# dados_variados (20, 2.17, False, 'Ana')

# %%
# Tupla de tuplas
tupla_de_tuplas = (
    ('Curso', 'Módulo 1', 'Módulo 2'),
    ('Data Science', 'Lógica de Programação I', 'Lógica de Programação II'),
    ('Web Full Stack', 'Front End Estático', 'Front End Dinâmico')
)
print(tupla_de_tuplas)
# Out:
# (('Curso', 'Módulo 1', 'Módulo 2'), ('Data Science', 'Lógica de Programação I', 'Lógica de Programação II'), ('Web Full Stack', 'Front End Estático', 'Front End Dinâmico'))

# %%
print(linguagens[0]) # imprime "Python"
print(linguagens[1]) # imprime "SQL"
print(dados_variados[2]) # imprime False
print(tupla_de_tuplas[2][0]) # imprime "Web Full Stack"
# Out:
# Python
# SQL
# False
# Web Full Stack

# %% [markdown]
# **Loop do tipo `for`**

# %%
cadastros = (
    ('Ana', 32, 'SP'),
    ('João', 25, 'RJ'),
    ('Maria', 19, 'PE')
)
for cadastro in cadastros:
  print(cadastro)
# Out:
# ('Ana', 32, 'SP')
# ('João', 25, 'RJ')
# ('Maria', 19, 'PE')

# %% [markdown]
# **Fatiando (slicing) dos dados**

# %%
print('Primeira pessoa cadastrada:', cadastros[0])
print('Nome da primeira pessoa cadastrada:', cadastros[0][0])
# Out:
# Primeira pessoa cadastrada: ('Ana', 32, 'SP')
# Nome da primeira pessoa cadastrada: Ana

# %% [markdown]
# Tuplas podem virar listas, e listas podem virar tuplas!

# %%
lista_frutas = ['abacate', 'banana', 'maca']
print(f'''
tipo:, {type(lista_frutas)}
conteudo: {lista_frutas}
''')

tupla_frutas = tuple(lista_frutas)

print(f'''
tipo:, {type(tupla_frutas)}
conteudo: {tupla_frutas}
''')
# Out:
# tipo:, <class 'list'>
# conteudo: ['abacate', 'banana', 'maca']
#
#
# tipo:, <class 'tuple'>
# conteudo: ('abacate', 'banana', 'maca')

# %% [markdown]
# A principal diferença é: tuplas são **imutáveis**!
#
# Para tuplas **não é possível**: alterar elementos individuais, adicionar elementos, remover elementos ou alterar a ordem dos elementos. Uma vez criada, não é possível alterar nada de uma tupla!

# %%
print('lista', lista_frutas)
print('tupla', tupla_frutas)
lista_frutas[0] = 'abacaxi'
print('lista modificada', lista_frutas)
print('-'*20)
tupla_frutas[0] = 'abacaxi'
# Out:
# lista ['abacate', 'banana', 'maca']
# tupla ('abacate', 'banana', 'maca')
# lista modificada ['abacaxi', 'banana', 'maca']
# --------------------
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\dario\OneDrive\Área de Trabalho\Dario\Datascience\Suzano-Ada\02 Logica de programação 2\1. Tuplas.ipynb Célula: 45 in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/dario/OneDrive/%C3%81rea%20de%20Trabalho/Dario/Datascience/Suzano-Ada/02%20Logica%20de%20programa%C3%A7%C3%A3o%202/1.%20Tuplas.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> print('lista modificada', lista_frutas)
#       <a href='vscode-notebook-cell:/c%3A/Users/dario/OneDrive/%C3%81rea%20de%20Trabalho/Dario/Datascience/Suzano-Ada/02%20Logica%20de%20programa%C3%A7%C3%A3o%202/1.%20Tuplas.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> print('-'*20)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dario/OneDrive/%C3%81rea%20de%20Trabalho/Dario/Datascience/Suzano-Ada/02%20Logica%20de%20programa%C3%A7%C3%A3o%202/1.%20Tuplas.ipynb#X62sZmlsZQ%3D%3D?line=5'>6</a> tupla_frutas[0] = 'abacaxi'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Qual a vantagem das tuplas?
#
# As tuplas e listas possuem operações úteis parecidas, `slicing`, `index`, `ordenação`. Sendo a principal diferença é que as listas conseguimos modificar o seu conteúdo enquanto as tuplas não conseguimos.
#
# Há duas diferenças que sugerem o uso de tuplas no lugar de listas:
# - Performance:
#   - Tuplas apresentam uma leve vantagem de acesso ("pegar" um elemento)
#   - Tuplas ocupam menos espaço na memória
# - Indicar de uma estrutura rígida:
#   - É um jeito de **sinalizar que esses dados não deveriam ser alterados**.
#   - É um meio de garantir que os elementos estarão **em uma ordem específica**.
#
#
#   - Quando utilizamos tuplas, queremos indicar que novos elementos não deveriam ser inseridos, assim como o seu conteúdo não deveria ser modificado
#
# Um exemplo de estrutura rígida, é no cadastro de pessoas.
# Em que coletamos, o nome, CPF, e idade, por exemplo. Neste o sistema não espera que hajam menos ou mais informações sendo rígida essa estrutura.
# Vamos explorar um pouco este caso abaixo.

# %%
# Cadastro
# - Nome
# - idade
# - Estado
continuar_cadastro = True

cadastros = []

while continuar_cadastro:
  cadastrar = input('Deseja inserir um novo cadastro?')
  if cadastrar.lower() in ['sim', 's', 'yes', 'y']:
    nome = input('Insira o nome: ')
    idade = int(input('Insira a idade: '))
    estado = input('Insira o estado: ')
    cadastro = (nome, idade, estado)
    cadastros.append(cadastro)
  elif cadastrar.lower() in ['não', 'n', 'nao', 'no']:
    print(f'Cadastro finalizado, inserido {len(cadastros)} novos')
    continuar_cadastro = False
  else:
    print(f'Opção invalida. Foi inserido "{cadastrar}",\
escolha entre [sim, s, yes, y] para cadastrar uma nova pessoa ou [não, nao, n, no] para parar')
# Out:
# Cadastro finalizado, inserido 1 novos

# %% [markdown]
# Conseguimos desempactor os elementos tanto de tuplas como de listas (do inglês *unpacking*).

# %%
pessoa = cadastros[0]
print(pessoa)
nome, idade, estado = pessoa
print(nome)
print(idade)
print(estado)
# Out:
# ('dario', 29, 'ba')
# dario
# 29
# ba

# %% [markdown]
# Outra forma é utilizar o operador `*` para o resto como o exemplo abaixo!
# Assim garantindo que não seja levantado um erro

# %%
linguagens = ('Python', 'JavaScript', 'HTML', 'CSS', 'R')

primeira, *resto = linguagens
print(primeira) # Python
print(resto) # ['JavaScript', 'HTML', 'CSS', 'R']

*resto, ultima = linguagens
print(resto) # ['Python', 'JavaScript', 'HTML', 'CSS']
print(ultima) # R

primeira, *meio, ultima = linguagens
print(primeira) # Python
print(meio) # ['JavaScript', 'HTML', 'CSS']
print(ultima) # R
# Out:
# Python
# ['JavaScript', 'HTML', 'CSS', 'R']
# ['Python', 'JavaScript', 'HTML', 'CSS']
# R
# Python
# ['JavaScript', 'HTML', 'CSS']
# R

# %% [markdown]
# Como lembrar a posição que cada valor significa na tupla?
#
# Essa é uma grande dificuldade (que será reduzida com os dicionários).
#
# Mas se uma das vantagens da tupla é a imutabilidade, e cada campo representar um valor específico (nome, idade, etc). Como relembrar sempre o que cada posição representa?
#
# Por este motivo temos o `named tuple` em Python, que podemos nomear a nossa tupla simplificando o processo e acesso aos valores como será visto abaixo

# %%
# Importando as tuplas nomeadas
from collections import namedtuple

# %%
# Pegando a primeira pessoa cadastrada
pessoa = cadastros[0]
print(pessoa)

Pessoa = namedtuple("Pessoa", ["nome", "idade", "estado"])
print(Pessoa)

pessoa = Pessoa("Gil", 36, "SP")
print(pessoa)
# Out:
# ('dario', 29, 'ba')
# <class '__main__.Pessoa'>
# Pessoa(nome='Gil', idade=36, estado='SP')

# %%
# Com o named tuple temos as mesmas funcionalidades das tuplas com vantagens!
pessoa2 = Pessoa(nome='Alex', idade=31, estado='RJ')
print(pessoa2)
# Out:
# Pessoa(nome='Alex', idade=31, estado='RJ')

# %%
Pessoa??
# Out:
# Init signature: Pessoa(nome, idade, estado)
# Docstring:      Pessoa(nome, idade, estado)
# Type:           type
# Subclasses:

# %%
# Conseguimos acessar os atributos por posição e pelo nome dado!
print(pessoa2[0])
print(pessoa2.nome)
# Out:
# Alex
# Alex

# %% [markdown]
# Voltando ao exemplo de cadastro utilizando `named tuple`

# %%
# Cadastro
# - Nome
# - idade
# - Estado
Pessoa = namedtuple('Pessoa', ['nome', 'idade', 'estado'])
continuar_cadastro = True

cadastros = []

while continuar_cadastro:
  cadastrar = input('Deseja inserir um novo cadastro?')
  if cadastrar.lower() in ['sim', 's', 'yes', 'y']:
    nome = input('Insira o nome: ')
    idade = int(input('Insira a idade: '))
    estado = input('Insira o estado: ')
    cadastro = Pessoa(nome=nome, idade=idade, estado=estado)
    cadastros.append(cadastro)
  elif cadastrar.lower() in ['não', 'n', 'nao', 'no']:
    print(f'Cadastro finalizado, inserido {len(cadastros)} novos')
    continuar_cadastro = False
  else:
    print(f'Opção invalida. Foi inserido "{cadastrar}",\
escolha entre [sim, s, yes, y] para cadastrar uma nova pessoa ou [não, nao, n, no] para parar')
# Out:
# Cadastro finalizado, inserido 2 novos

# %% [markdown]
# **Drops**
#
# Crie três funções:
# - Pegue a idade minima das pessoas cadastradas
# - Pegue a idade máxima das pessoas cadastradas
# - Calcule a idade média das pessoas cadastradas

# %%
from typing import List
def pegue_idade_minima(cadastros: List[Pessoa]) -> int:
  idades = [] # PREENCHA AQUI
  for pessoa in cadastros:
    idade = pessoa.idade # PREENCHA AQUI
    idades.append(idade) # PREENCHA AQUI
  idade_minima = min(idades) # PREENCHA AQUI
  return idade_minima # PREENCHA AQUI

def pegue_idade_maxima(cadastros: List[Pessoa]) -> int:
  idades = [] # PREENCHA AQUI
  for pessoa in cadastros:
    idade = pessoa.idade # PREENCHA AQUI
    idades.append(idade) # PREENCHA AQUI
  idade_maxima = max(idades) # PREENCHA AQUI
  return idade_maxima # PREENCHA AQUI
  
def pegue_idade_media(cadastros: List[Pessoa]) -> float:
  idades = [] # PREENCHA AQUI
  for pessoa in cadastros:
    idade = pessoa.idade # PREENCHA AQUI
    idades.append(idade) # PREENCHA AQUI
  idade_media = sum(idades)/len(idades) # PREENCHA AQUI
  return idade_media # PREENCHA AQUI

# %%
pegue_idade_minima(cadastros)
# Out:
# 26

# %%
pegue_idade_maxima(cadastros)
# Out:
# 29

# %%
pegue_idade_media(cadastros)
# Out:
# 27.5

# %% [markdown]
# Outra utilidade de tuplas: fazer uma função **retornar mais de um valor**

# %%
def seq(x):
    return x, 2*x, 3*x

# %%
seq(2)
# Out:
# (2, 4, 6)

# %%
resultados = seq(2)

# %%
resultados
# Out:
# (2, 4, 6)

# %%
# Enumerate retorna uma tupla
tupla = (10, 20, 30, 'Alex')
for valor in enumerate(tupla):
    print(valor)

print('-'*36)
for valor in enumerate(tupla):
    print(valor[0], valor[1])

print('-'*36)
for i, elemento in enumerate(tupla):
    print(i, elemento)
# Out:
# (0, 10)
# (1, 20)
# (2, 30)
# (3, 'Alex')
# ------------------------------------
# 0 10
# 1 20
# 2 30
# 3 Alex
# ------------------------------------
# 0 10
# 1 20
# 2 30
# 3 Alex

# %% [markdown]
# **Enunciado**
#
# Modifique a função cadastrar_usuario abaixo em que serão coletados as seguintes informações a partir da entrada da pessoa usuária (input):
# - Nome
# - Idade
# - Sexo
#
#
# Nesse cadastro busque utilizar namedtuple ou tuplas. Além de aceitar múltiplas entradas do usuário (aceite a opção cadastrar, parar, e lide com uma opção invalida)
#
# Agora crie uma função que permita descobrir a idade média de pessoas cadastradas pelo sexo (para manter simples, masculino e feminino, representado por m e f, respectivamente).
#
# Nessa função, perceba que o sexo pode ter sido cadastrado de forma incorreta, como proceder?
#
# Na função calcule_media_idade_por_sexo o retorno deve ser uma tupla de tuplas no formato
#
# (('m', <media_masculino>), ('f', <media_feminino>))

# %%
from collections import namedtuple

def cadastrar_usuario():
  continuar = True

  cadastros = []
  Cliente = namedtuple('Cliente', ['nome', 'idade', 'sexo'])
  
  while continuar:
    cadastrar = input('Deseja cadastrar novo usuário?')
    if cadastrar.lower() in ['sim', 's', 'yes', 'y']:
      nome = input('Digite seu nome: ')
      idade = int(input('Digite sua idade: '))
      sexo = input('Digite o sexo (m/f)')
      cadastro = Cliente(nome=nome, idade=idade, sexo=sexo)
      cadastros.append(cadastro)
    elif cadastrar.lower() in ['nao', 'n', 'não', 'no']:
      print(f'Cadastro finalizado, inserido {len(cadastros)} novos')
      continuar = False
    else: 
      print(f'Opção invalida. Foi inserido "{cadastrar}",\
digite [sim, s, yes, y] para cadastrar um cliente ou [não, nao, n, no] para parar o cadastro')

  return cadastros

# %%
cadastros = cadastrar_usuario()
# Out:
# Cadastro finalizado, inserido 6 novos

# %%
cadastros
# Out:
# [Cliente(nome='dario', idade=22, sexo='m'),
#  Cliente(nome='dario2', idade=32, sexo='f'),
#  Cliente(nome='dario3', idade=55, sexo='f'),
#  Cliente(nome='dario4', idade=10, sexo='m'),
#  Cliente(nome='dario5', idade=39, sexo='masc'),
#  Cliente(nome='dario5', idade=901, sexo='einf')]

# %%
def calcule_media_idade_por_sexo(cadastros):
    idade_feminino = []
    idade_masculino = []
    incorreto = []

    for cliente in cadastros:
        idade = cliente.idade
        if cliente.sexo.lower() == 'm':
            idade_masculino.append(idade)
        elif cliente.sexo.lower() == 'f':
            idade_feminino.append(idade)
        else:
            incorreto.append(idade)

    if len(idade_masculino) > 0 :
        media_masculino = sum(idade_masculino)/len(idade_masculino)
    else:
        media_masculino = 'Não existe'

    if len(idade_feminino) > 0:
        media_feminino = sum(idade_feminino)/len(idade_feminino)
        
        n_incorretos = len(incorreto)

    return (('f', media_feminino), ('m', media_masculino), ('numero de entradas incorretas:', n_incorretos))

# %%
calcule_media_idade_por_sexo(cadastros)
# Out:
# (('f', 43.5), ('m', 16.0), ('numero de entradas incorretas', 2))
